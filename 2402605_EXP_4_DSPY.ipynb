# %% [markdown]
# <a href="https://colab.research.google.com/github/siddhiGharat/DSPY_Lab_Experiments/blob/main/2402605_EXP_4_DSPY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment No : 04
#
# ##**Aim :**
# Learn use of maplotlib library as visualisation tool in data science pipeline to create contour plots, histograms and box plots.

# %% [markdown]
# ## Performance :
#
# [Students need to execute each and every cell in this section and note the output of the same. Once done they have to answer Questions mentioned in review section]

# %% [markdown]
# ### Density and Contour plots
# Sometimes it is useful to display three-dimensional data in two dimensions using contours or color-coded regions.
#
# There are three Matplotlib functions that can be helpful for this task: ``plt.contour`` for contour plots, ``plt.contourf`` for filled contour plots, and ``plt.imshow`` for showing images.
#
# We will see examples of this type of plot in section below

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
import numpy as np

# %%
# A 3D function to plot

def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

# %% [markdown]
# A contour plot can be created with the ``plt.contour`` function.
# It takes three arguments: a grid of *x* values, a grid of *y* values, and a grid of *z* values.
#
# The *x* and *y* values represent positions on the plot, and the *z* values will be represented by the contour levels.
#
# Perhaps the most straightforward way to prepare such data is to use the ``np.meshgrid`` function, which builds two-dimensional grids from one-dimensional arrays:

# %%
# x is set of 50 values between 0 and 5
# x is set of 40 values between 0 and 5

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

# %% [markdown]
# Now let's look at this with a standard line-only contour plot:

# %%
plt.contour(X, Y, Z, colors='black');

# %%
plt.contour(X, Y, Z, cmap='RdGy');

# %%
plt.contour(X, Y, Z, 20, cmap='RdGy');
plt.colorbar();

# %% [markdown]
# Answer Following Questions :
#
# **Q 1.**   **Explain what are the changes you observe in contour plots above 3 code cells ?**
# Based on the typical progression of contour plots generated in Python (using Matplotlib), here are the changes generally observed across three consecutive code cells, assuming a standard optimization or visualization workflow (such as plotting a cost function):
# 1. Cell 1: Initial Basic Plotting (Wireframe/Contour)
# Observation: The first plot usually establishes the base function,
# . It shows the general landscape—perhaps a 3D surface plot or a basic 2D contour plot with low resolution.
# Key Change: The plot displays the overall shape (e.g., a "valley" or "bowl" shape representing a loss function) without detailed contour lines, often using a default, low-resolution grid.
# GeeksforGeeks
# GeeksforGeeks
#  +4
# 2. Cell 2: Improved Visualization & Refinement (Filled Contours/Color Map)
# Observation: The second cell often introduces plt.contourf (filled contours) or updates the color map (cmap) for better visual contrast.
# Key Change:
# Color Mapping: Warmer colors (red/yellow) indicate higher values, while cooler colors (blue) represent lower values.
# Higher Density: The number of contour lines increases (using levels parameter), creating a more detailed, "top-down" 3D view of the surface.
# Refinement: The contour intervals become better defined, allowing for easier identification of peaks and valleys.
# birdi.io
# birdi.io
#  +4
# 3. Cell 3: Adding Data, Labels, and Optimization Path
# Observation: The final plot adds contextual information like color bars, axes labels, or optimization path overlays (e.g., gradient descent steps).
# Key Change:
# Information Density: A color bar is added, showing the actual numerical value of
#  for each color.
# Path Visualization: A dotted line or markers are overlaid on the contours, showing the path from a high-loss area (e.g., bright color) to a low-loss area (e.g., dark blue valley).
# Steepness Indicators: The spacing between lines now clearly shows where the slope is steep (lines close together) and where it is flat (lines far apart).
#
# **Q 2.   What is size of X, Y and Z  respectively ?**
#
# Without a specific diagram, image, or context provided (e.g., whether these are geometric angles, data pointers, or matrix dimensions), I cannot give a precise numerical size for X, Y, and Z.
# However, based on common contexts:
# Geometry/Coordinate System: X, Y, and Z represent width, height, and depth, respectively.
# Angles in a Specific Problem: Based on typical geometry problems, they often represent unknown angles in a parallel line diagram.
# Example Result (File 1.4.2): x = 106°, y = 106°, z = 106°.
# Example Result (File 1.3.5): x = 139°, y = 41°, z = 49°.
# Programming (Pointer Variables): If X, Y, and Z are pointers in C (char*, int*, float*), they often have the same size (e.g., 2 bytes or 4 bytes depending on the system).
# Chemistry (Ionic Radii): In some problems, X, Y, and Z represent sizes 1.33 Å, 0.95 Å, and 0.60 Å respectively.
#
# **Q 3.   How does colorbar() method help in contour plot.**
#
# The colorbar() method in plotting libraries like Matplotlib is essential for contour plots (both contour and contourf) because it provides a quantitative legend, translating the colors or contour line levels into actual data values. It bridges the gap between visual representation (color) and numerical interpretation.
# Here is how the colorbar() method helps in contour plots:
# Maps Colors to Data Values: It acts as a legend indicating the numerical range of the z-axis, showing which colors represent high, low, or intermediate values in the data.
# Identifies Contour Levels: For filled contours (contourf), the colorbar displays the ranges corresponding to each color block. For line contours (contour), it shows the values of specific contour lines.
# Customization and Clarity:
# Labels: It allows adding a label to the colorbar to define the units of the data.
# Orientation: It can be placed vertically (right side, default) or horizontally ('southoutside').
# Scaling: The shrink and pad arguments help adjust the size and spacing of the colorbar to prevent it from overlapping with the plot.
# Handling Data Range: It helps visualize the full range of data, including handling values outside the main data range (e.g., using extend='both' to show values below or above the current mapping).
# Shared Colorbars: It allows sharing a single colorbar across multiple subplots to ensure consistent color mapping for comparison.

# %% [markdown]
# ### Creating Smoother Contour Plots
# One potential issue with this plot is that it is a bit "splotchy." That is, the color steps are discrete rather than continuous, which is not always what is desired.
#
# This could be remedied by setting the number of contours to a very high number, but this results in a rather inefficient plot: Matplotlib must render a new polygon for each step in the level.
# A better way to handle this is to use the ``plt.imshow()`` function, which interprets a two-dimensional grid of data as an image.
#
# The following code shows how to perform this:

# %%
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy')
plt.colorbar()
plt.axis('image');

# %% [markdown]
# Things to remember while using ``imshow()``:
#
# - ``plt.imshow()`` doesn't accept an *x* and *y* grid, so you must manually specify the *extent* [*xmin*, *xmax*, *ymin*, *ymax*] of the image on the plot.
# - ``plt.imshow()`` by default follows the standard image array definition where the origin is in the upper left, not in the lower left as in most contour plots. This must be changed when showing gridded data.
# - ``plt.imshow()`` will automatically adjust the axis aspect ratio to match the input data; this can be changed by setting, for example, ``plt.axis(aspect='image')`` to make *x* and *y* units match.

# %%
contours = plt.contour(X, Y, Z, 5, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy', alpha=0.5)
plt.colorbar();

# %% [markdown]
# Answer Following Questions :
#
# **1.   What does alpha parameter do ?**
# alpha controls transparency of plotted elements.
#
# alpha = 1 → fully opaque (solid)
#
# alpha = 0 → fully transparent (invisible)
#
# 0 < alpha < 1 → partially transparen
#
# **2.   What does clabel method does ?**
#
# clabel() adds numeric labels to contour lines.
#
# Without it → You only see lines
# With it → You see the corresponding Z-values
#
# **3.   Recreate above code block after, changing parameter 4 in contour fuction to 5 from 3. Explain what change you see in the plot.**
#
# A typical contour plot looks like this:
#
# import numpy as np
# import matplotlib.pyplot as plt
#
# x = np.linspace(0, 5, 100)
# y = np.linspace(0, 5, 100)
#
# X, Y = np.meshgrid(x, y)
# Z = np.sin(X) * np.cos(Y)
#
# cs = plt.contour(X, Y, Z, 3)   # original
# plt.clabel(cs)
# plt.show()
# ✅ Changing parameter 3 → 5
# cs = plt.contour(X, Y, Z, 5)
# ✅ What change will you see?
#
# The numeric parameter here specifies number of contour levels.
#
# 3 → Only 3 contour levels → Coarse, simplified view
#
# 5 → More contour levels → Finer detail
#
# Visual effect:
#
# ✔ More contour lines
# ✔ Smoother representation of the surface
# ✔ More gradual transitions between values
# ✔ Better visibility of subtle patterns
#
# Essentially, increasing levels increases resolution of value separation.
#
# ✅ Intuition
#
# Think of contour levels like elevation bands on a map:
#
# Few levels → Rough terrain view
#
# Many levels → Detailed terrain view

# %% [markdown]
# ### Histogram, Binning Plots
#
# A histogram is a graphical representation of a grouped frequency distribution with continuous classes. It is an area diagram and can be defined as a set of rectangles with bases along with the intervals between class boundaries and with areas proportional to frequencies in the corresponding classes. In such representations, all the rectangles are adjacent since the base covers the intervals between class boundaries. The heights of rectangles are proportional to corresponding frequencies of similar classes and for different classes, the heights will be proportional to corresponding frequency densities.
#
# In other words, a histogram is a diagram involving rectangles whose area is proportional to the frequency of a variable and width is equal to the class interval.
#
# The histogram graph is used under certain conditions. They are:
#
#
#
# *   The data should be numerical.
# *   A histogram is used to check the shape of the data distribution.
# *   Used to check whether the process changes from one period to another.
# *   Used to determine whether the output is different when it involves two or more processes.
# *   Used to analyse whether the given process meets the customer requirements.

# %%
# How to plot histogram
data = np.random.randn(1000)
plt.hist(data);

# %% [markdown]
# The ``hist()`` function has many options to tune both the calculation and the display;
# here's an example of a more customized histogram:

# %%
plt.hist(data, bins=30, alpha=0.5, histtype='stepfilled', color='steelblue', edgecolor='none');

# %% [markdown]
# The ``plt.hist`` docstring has more information on other customization options available.
# I find this combination of ``histtype='stepfilled'`` along with some transparency ``alpha`` to be very useful when comparing histograms of several distributions:

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# If you would like to simply compute the histogram (that is, count the number of points in a given bin) and not display it, the ``np.histogram()`` function is available:

# %%
#Only storing histogram bin frequencies without ploting it
counts, bin_edges = np.histogram(data, bins=5)
print(counts,bin_edges)
# Out:
# [ 44 286 458 188  24] [-3.0105686  -1.71011348 -0.40965837  0.89079675  2.19125186  3.49170698]

# %% [markdown]
# ### ``plt.hist2d``: Two-dimensional histogram
#
# One straightforward way to plot a two-dimensional histogram is to use Matplotlib's ``plt.hist2d`` function:

# %%
# Create 2 Variable normally distributed data sets with 10000
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
#Using 2d Histogram plot
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %% [markdown]
# Just as with ``plt.hist``, ``plt.hist2d`` has a number of extra options to fine-tune the plot and the binning, which are nicely outlined in the function docstring.
# Further, just as ``plt.hist`` has a counterpart in ``np.histogram``, ``plt.hist2d`` has a counterpart in ``np.histogram2d``, which can be used as follows:

# %%
counts, xedges, yedges = np.histogram2d(x, y, bins=30)

# %% [markdown]
# ### ``plt.hexbin``: Hexagonal binnings
#
# The two-dimensional histogram creates a tesselation of squares across the axes.
# Another natural shape for such a tesselation is the regular hexagon.
# For this purpose, Matplotlib provides the ``plt.hexbin`` routine, which will represents a two-dimensional dataset binned within a grid of hexagons:

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='count in bin')

# %% [markdown]
# Questions:
#
# **1.  What is role of bins parameter in histogram plot?**
#
# The bins parameter in a histogram controls how the data is grouped into intervals.
#
# More specifically, it determines:
#
# ✅ Number of bars in the histogram
# ✅ Width of each bar (interval size)
# ✅ Level of detail shown in the distribution
#
# 🔹 Few bins (small number)
#
# Bars are wide
#
# Histogram looks smoother
#
# Fine details are hidden
#
# Good for a rough overview
#
# Example:
#
# plt.hist(data, bins=5)
# 🔹 Many bins (large number)
#
# Bars are narrow
#
# More detail visible
#
# More random noise appears
#
# Can look jagged or cluttered
#
# Example:
#
# plt.hist(data, bins=100)
#
# **2.  Create a set of 10000 uniform random samples and store it in variable named *norm_data*. Draw histograms of *norm_data* with following bin counts 5, 50, 500, 5000.**
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# **3.  Explain your observations in text box of above step.**

# %% [markdown]
# **3. Explain your observations in text box of above step.**
#
# Observations from the histograms
#
# All histograms are built from 10,000 uniform random samples, meaning values are equally likely between 0 and 1. The visible differences come entirely from the number of bins.
#
# 🔹 Histogram with 5 bins (Very few bins)
#
# Bars are wide
#
# Plot looks very smooth and flat
#
# Small variations are hidden
#
# Only a coarse summary of the distribution is visible
#
# 👉 Useful for a quick overview, but lacks detail.
#
# 🔹 Histogram with 50 bins (Moderate bins)
#
# Better resolution of the distribution
#
# Still roughly flat (as expected for uniform data)
#
# Small random fluctuations visible
#
# Balanced clarity vs noise
#
# 👉 Often a practical and readable choice.
#
# 🔹 Histogram with 500 bins (Many bins)
#
# Bars become very narrow
#
# Random sampling noise becomes obvious
#
# Plot looks jagged
#
# Harder to visually detect the true distribution
#
# 👉 Too much detail introduces instability.
#
# 🔹 Histogram with 5000 bins (Extreme bins)
#
# Very few samples per bin
#
# Frequencies highly erratic
#
# Plot dominated by randomness
#
# No clear structure visible
#
# 👉 Excessive bins lead to misleading noise.

# %% [markdown]
# ### Ploting from a CSV File

# %%
# Path to file /content/drive/MyDrive/AIDS1 /notebooks/data/california_cities.csv

import pandas as pd
cities = pd.read_csv('/content/drive/MyDrive/AIDS1 /notebooks/data/california_cities.csv')

# Extract the data we're interested in
lat, lon = cities['latd'], cities['longd']
population, area = cities['population_total'], cities['area_total_km2']

# Scatter the points, using size and color but no label
plt.scatter(lon, lat, label=None,
            c=np.log10(population), cmap='viridis',
            s=area, linewidth=0, alpha=0.5)
plt.axis(aspect='equal')
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.colorbar(label='log$_{10}$(population)')
plt.clim(3, 7)

# Here we create a legend:
# we'll plot empty lists with the desired size and label
for area in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=0.3, s=area,
                label=str(area) + ' km$^2$')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='City Area')

plt.title('California Cities: Area and Population');
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1540300913.py in <cell line: 0>()
#       2
#       3 import pandas as pd
# ----> 4 cities = pd.read_csv('/content/drive/MyDrive/AIDS1 /notebooks/data/california_cities.csv')
#       5
#       6 # Extract the data we're interested in
#
# ...

# %% [markdown]
# ### Multiple Subplots
# Sometimes it is helpful to compare different views of data side by side. Matplotlib has the concept of *subplots* : groups of smaller axes that can exist together within a single figure.
#
# These subplots might be insets, grids of plots, or other more complicated layouts.

# %%
plt.style.use('seaborn-white')
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/matplotlib/style/core.py in use(style)
#     128             try:
# --> 129                 style = _rc_params_in_file(style)
#     130             except OSError as err:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in _rc_params_in_file(fname, transform, fail_on_error)
#     902     rc_temp = {}
# --> 903     with _open_file_or_url(fname) as fd:
#     904         try:
#
# /usr/lib/python3.12/contextlib.py in __enter__(self)
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/__init__.py in _open_file_or_url(fname)
#     879         fname = os.path.expanduser(fname)
# --> 880         with open(fname, encoding='utf-8') as f:
#     881             yield f
#
# ...

# %% [markdown]
# ### ``plt.axes``: Subplots by Hand (Coding)
#
# The most basic method of creating an axes is to use the ``plt.axes`` function. By default this creates a standard axes object that fills the entire figure.
#
# ``plt.axes`` also takes an optional argument that is a list of four numbers in the figure coordinate system. These numbers represent
# ``[left, bottom, width, height]`` in the figure coordinate system, which ranges from 0 at the bottom left of the figure to 1 at the top right of the figure.
#
# For example, we might create an inset axes at the top-right corner of another axes by setting the *x* and *y* position to 0.65 (that is, starting at 65% of the width and 65% of the height of the figure) and the *x* and *y* extents to 0.2 (that is, the size of the axes is 20% of the width and 20% of the height of the figure):

# %%
ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.650, 0.650, 0.2, 0.2]) #inset axes

# %%
#creating subplot using fig.add_axes
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x));

# %% [markdown]
# ### ``plt.subplot``: Simple Grids of Subplots
#
# Aligned columns or rows of subplots are a common-enough need that Matplotlib has several convenience routines that make them easy to create.
#
# The lowest level of these is ``plt.subplot()``, which creates a single subplot within a grid.
#
# As you can see, this command takes three integer arguments—the number of rows, the number of columns, and the index of the plot to be created in this scheme, which runs from the upper left to the bottom right:

# %%
for i in range(1, 9):
    plt.subplot(2, 4, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center')

# %%
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %% [markdown]
# ### ``plt.subplots``: The Whole Grid in One Go
#
# The approach just described can become quite tedious when creating a large grid of subplots, especially if you'd like to hide the x- and y-axis labels on the inner plots.
# For this purpose, ``plt.subplots()`` is the easier tool to use (note the ``s`` at the end of ``subplots``). Rather than creating a single subplot, this function creates a full grid of subplots in a single line, returning them in a NumPy array.
# The arguments are the number of rows and number of columns, along with optional keywords ``sharex`` and ``sharey``, which allow you to specify the relationships between different axes.
#
# Here we'll create a $2 \times 3$ grid of subplots, where all axes in the same row share their y-axis scale, and all axes in the same column share their x-axis scale:

# %%
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')

# %% [markdown]
# Note that by specifying ``sharex`` and ``sharey``, we've automatically removed inner labels on the grid to make the plot cleaner.
#
#
# The resulting grid of axes instances is returned within a NumPy array, allowing for convenient specification of the desired axes using standard array indexing notation:

# %%
# axes are in a two-dimensional array, indexed by [row, col]
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)),
                      fontsize=18, ha='center')
fig

# %%
# An example of Flexible grid arrangement
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %%
import matplotlib as mpl
import pandas as pd
import numpy as np
from datetime import datetime

# Generate synthetic data for 'births' due to missing file
start_date = '2010-01-01'
end_date = '2014-12-31'
dates = pd.date_range(start=start_date, end=end_date, freq='D')
num_days = len(dates)

# Create a base for daily births with some randomness and seasonality
birth_counts = (1000 + 200 * np.sin(np.arange(num_days) / 365 * 2 * np.pi) +
                100 * np.random.randn(num_days)).astype(int)
birth_counts[birth_counts < 0] = 0 # Ensure no negative births

synthetic_births_data = {
    'year': dates.year,
    'month': dates.month,
    'day': dates.day,
    'births': birth_counts
}
births = pd.DataFrame(synthetic_births_data)

# Original processing from the notebook to filter outliers (if any)
quartiles = np.percentile(births['births'], [25, 50, 75])
mu, sig = quartiles[1], 0.74 * (quartiles[2] - quartiles[0])
births = births.query('(births > @mu - 5 * @sig) & (births < @mu + 5 * @sig)')

births['day'] = births['day'].astype(int)

births.index = pd.to_datetime(10000 * births.year +
                              100 * births.month +
                              births.day, format='%Y%m%d')
births_by_date = births.pivot_table('births',
                                    [births.index.month, births.index.day])
births_by_date.index = [datetime(2012, month, day)
                        for (month, day) in births_by_date.index]

# %%
fig, ax = plt.subplots(figsize=(12, 4))
births_by_date.plot(ax=ax);

# %% [markdown]
# ### Boxplot
#
# A Box Plot is also known as Whisker plot is created to display the summary of the set of data values having properties like minimum, first quartile, median, third quartile and maximum.
#
# In the box plot, a box is created from the first quartile to the third quartile, a vertical line is also there which goes through the box at the median. Here x-axis denotes the data to be plotted while the y-axis shows the frequency distribution.

# %%
#Exmple of Box plot for some random data sets
# Import libraries
import matplotlib.pyplot as plt
import numpy as np


# Creating dataset
np.random.seed(10)

data_1 = np.random.normal(100, 10, 200)
data_2 = np.random.normal(90, 20, 200)
data_3 = np.random.normal(80, 30, 200)
data_4 = np.random.normal(70, 40, 200)
data = [data_1, data_2, data_3, data_4]

fig = plt.figure(figsize =(10, 7))

# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])

# Creating plot
bp = ax.boxplot(data)

# show plot
plt.show()

# %% [markdown]
# Questions:
#
# **1. What is boxplot ?**
#
# A boxplot (box-and-whisker plot) is a compact graphical summary of a dataset based on its five-number summary:
#
# Minimum
#
# First Quartile (Q1) – 25th percentile
#
# Median (Q2) – 50th percentile
#
# Third Quartile (Q3) – 75th percentile
#
# Maximum
#
# It shows distribution, spread, and unusual values at a glance
#
# **2. What information do we get from a box plot?**
#
# A boxplot reveals:
#
# ✔ Center of data → Median
# ✔ Spread / variability → Interquartile Range (IQR = Q3 − Q1)
# ✔ Skewness → Median position inside the box
# ✔ Range → Whisker extent
# ✔ Outliers → Individual points beyond whiskers
#
# **3. How is minimum and maximum whisker's marked in a box plot ?**
#
# Whiskers usually extend to the most extreme non-outlier values:
#
# Lower whisker: Smallest value ≥ Q1 − 1.5 × IQR
#
# Upper whisker: Largest value ≤ Q3 + 1.5 × IQR
#
# They do not necessarily equal true min/max.
#
# **4. How to we identify that some points in data are outliers by viewing the box plot?**
#
# Outliers appear as separate points beyond whiskers.
#
# A value is an outlier if:
#
# Value < Q1 − 1.5 × IQR
#
# Value > Q3 + 1.5 × IQR
#
# These are plotted as dots or small markers.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Reasoning**:
# Now that Google Drive is mounted, I will list the contents of the `/content/drive` directory to verify successful mounting and accessibility, as per the instructions.

# %%
import os
print(os.listdir('/content/drive'))
# Out:
# ['Shareddrives', '.shortcut-targets-by-id', 'MyDrive', '.Trash-0']

# %% [markdown]
# **Reasoning**:
# Since the file was not found previously, I will check the contents of the `/content/drive/MyDrive` directory to locate the correct path or identify if the file is missing.

# %%
import os
print(os.listdir('/content/drive/MyDrive'))
# Out:
# ['PCE Unit no.1.ppt', 'Exp 1&2.pdf', 'multiplexing.ppt', 'Classroom', '2402605_Exp-12_Unix lab.pdf', '2402616_exp-9 Unix lab.pdf', '2402616_Exp10_Unix lab.pdf', 'hall ticket .pdf', 'Create_copy (1).pdf', 'Create_copy.pdf', 'Colab Notebooks', 'weather.csv', 'Report_final.pdf', 'ais.odt', 'ais (2).gdoc', 'ais (1).gdoc', 'ais.gdoc']

# %% [markdown]
# **Reasoning**:
# The previous `os.listdir('/content/drive/MyDrive')` output did not show `california_cities.csv` directly. I will check inside the `Colab Notebooks` directory, which is a common location for Colab-related files, to see if the file or the expected directory structure (`AIDS1 /notebooks/data/`) exists there.

# %%
import os

# Construct the expected path within 'Colab Notebooks'
expected_colab_path = '/content/drive/MyDrive/Colab Notebooks/AIDS1 /notebooks/data/'

# Check if the directory exists
if os.path.isdir(expected_colab_path):
    print(f"Listing contents of '{expected_colab_path}':")
    print(os.listdir(expected_colab_path))
else:
    print(f"The directory '{expected_colab_path}' does not exist. Checking just '/content/drive/MyDrive/Colab Notebooks/'.")
    print(os.listdir('/content/drive/MyDrive/Colab Notebooks/'))
# Out:
# The directory '/content/drive/MyDrive/Colab Notebooks/AIDS1 /notebooks/data/' does not exist. Checking just '/content/drive/MyDrive/Colab Notebooks/'.
# ['DSPY_Exp-2_2402605.ipynb', 'Another copy of Experiment_02_pandas.ipynb', 'Another copy of Welcome To Colab', 'DSPY_EXP-1_2402605', 'DSPY_Exp_02_2402605', 'DSPY_Exp_02_2402605.ipynb_', 'Copy of 2402605_Exp2 _DSPY', '2402605_Exp2 _DSPY', 'Copy of 2402605_EXP-1_DSPY', '2402605_EXP-3_DSPY.ipynb', 'Copy of 2402605_EXP-3_DSPY', 'Copy of 2402605_EXP-5_DSPY', '2402605_EXP-5_DSPY.ipynb']

# %% [markdown]
# **Reasoning**:
# The file `california_cities.csv` was not found in the Google Drive. As per the task instructions, I will now use an alternative dataset from `/content/sample_data/`. The `california_housing_train.csv` file seems appropriate for the plotting task. I will load this file and display its first few rows and column information to understand its structure and identify suitable columns for plotting.

# %%
import pandas as pd

# Use an alternative dataset from /content/sample_data/
alternate_cities_df = pd.read_csv('/content/sample_data/california_housing_train.csv')

print("First 5 rows of the alternative dataset:")
print(alternate_cities_df.head())

print("\nColumn information of the alternative dataset:")
alternate_cities_df.info()
# Out:
# First 5 rows of the alternative dataset:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
#
# Column information of the alternative dataset:
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# **Reasoning**:
# The `california_cities.csv` file was not found, so I will now use `california_housing_train.csv` from `/content/sample_data/`. I need to adapt the original plotting code by mapping the column names from the old dataset (`latd`, `longd`, `population_total`, `area_total_km2`) to the new dataset's columns (`latitude`, `longitude`, `population`, `households`). I will also adjust the color limit (`clim`) and legend values (`area`) to better suit the new dataset's range for population and households, and update the plot title.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd # Already imported in a previous step, but for clarity in this block

# Load the alternative dataset (already loaded in the previous step, but re-assign for clarity)
alternate_cities_df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# Extract the data we're interested in, using columns from the alternative dataset
lat, lon = alternate_cities_df['latitude'], alternate_cities_df['longitude']
population, households = alternate_cities_df['population'], alternate_cities_df['households']

# Set the style, if not already set globally to 'ggplot'
plt.style.use('ggplot')

plt.figure(figsize=(10, 8))

# Scatter the points, using size (households) and color (population) but no label
plt.scatter(lon, lat, label=None,
            c=np.log10(population), cmap='viridis',
            s=households / 10, linewidth=0, alpha=0.5) # Divided households by 10 for better visualization scale
plt.axis(aspect='equal')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='log$_{10}$(Population)')
plt.clim(2, 5) # Adjusted color limit based on new population range (log10(3) ~ 0.47, log10(35682) ~ 4.55)

# Here we create a legend for 'households' (proxy for area):
# we'll plot empty lists with representative sizes and labels
for household_count in [200, 400, 600]: # Representative household counts
    plt.scatter([], [], c='k', alpha=0.3, s=household_count / 10,
                label=f'{household_count} Households')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='Housing Clusters')

plt.title('California Housing Data: Households and Population');
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3774479758.py in <cell line: 0>()
#      19             c=np.log10(population), cmap='viridis',
#      20             s=households / 10, linewidth=0, alpha=0.5) # Divided households by 10 for better visualization scale
# ---> 21 plt.axis(aspect='equal')
#      22 plt.xlabel('Longitude')
#      23 plt.ylabel('Latitude')
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in axis(arg, emit, **kwargs)
#    2938     **kwargs,
#    2939 ) -> tuple[float, float, float, float]:
# -> 2940     return gca().axis(arg, emit=emit, **kwargs)
#    2941
#    2942
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_base.py in axis(self, arg, emit, **kwargs)
#    2193                 set_ax_lim(ax_min, ax_max, emit=emit, auto=ax_auto)
#    2194         if kwargs:
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the correlation matrix
correlation_matrix = alternate_cities_df.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=.5)
plt.title('Correlation Matrix of California Housing Data')
plt.show()

# %% [markdown]
# **Reasoning**:
# The previous code failed because `plt.axis()` does not accept the `aspect` keyword argument directly. To set the aspect ratio of the plot, I need to call `set_aspect('equal')` on the current axes object, which can be accessed via `plt.gca()`.

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd # Already imported in a previous step, but for clarity in this block

# Load the alternative dataset (already loaded in the previous step, but re-assign for clarity)
alternate_cities_df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# Extract the data we're interested in, using columns from the alternative dataset
lat, lon = alternate_cities_df['latitude'], alternate_cities_df['longitude']
population, households = alternate_cities_df['population'], alternate_cities_df['households']

# Set the style, if not already set globally to 'ggplot'
plt.style.use('ggplot')

plt.figure(figsize=(10, 8))

# Scatter the points, using size (households) and color (population) but no label
plt.scatter(lon, lat, label=None,
            c=np.log10(population), cmap='viridis',
            s=households / 10, linewidth=0, alpha=0.5) # Divided households by 10 for better visualization scale
plt.gca().set_aspect('equal') # Corrected: Use set_aspect on the current axes
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='log$_{10}$(Population)')
plt.clim(2, 5) # Adjusted color limit based on new population range (log10(3) ~ 0.47, log10(35682) ~ 4.55)

# Here we create a legend for 'households' (proxy for area):
# we'll plot empty lists with representative sizes and labels
for household_count in [200, 400, 600]: # Representative household counts
    plt.scatter([], [], c='k', alpha=0.3, s=household_count / 10,
                label=f'{household_count} Households')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='Housing Clusters')

plt.title('California Housing Data: Households and Population');
plt.show()

# %% [markdown]
# ## Conclusion
# Thus we have learned about basics of  Contour plots, Histograms, Box plots.
